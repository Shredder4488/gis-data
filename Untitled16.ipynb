# %%
import geopandas as gpd

# %%
help(gpd)
# Out:
# Help on package geopandas:
#
# NAME
#     geopandas
#
# PACKAGE CONTENTS
#     _compat
#     _config
#     _vectorized
#     _version
#     array
#     base
#     conftest
#     datasets (package)
#     geodataframe
#     geoseries
#     io (package)
#     plotting
#     sindex
#     testing
#     tests (package)
#     tools (package)
#
# DATA
#     options = Options(
#       display_precision: None [default: Non...USE_PYGEO...
#
# VERSION
#     0.9.0
#
# FILE
#     c:\users\parul\anaconda3\lib\site-packages\geopandas\__init__.py

# %%
data = gpd.read_file('C:/Users/parul/anaconda3/machine learning and python projects/Untitled Folder/Test_Service_File_geodatabase.gdb')

# %%
DATA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ff32d931dd85> in <module>
# ----> 1 DATA
#
# NameError: name 'DATA' is not defined

# %%
data
# Out:
#        OBJECTID    PSS_Name PSS_Code                   Feed_Name Feed_Code  \
# 0         24805   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 1         24806   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 2         24807   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 3         24808   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 4         24809   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# ...         ...         ...      ...                         ...       ...
# 65280    228815  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65281    229030  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65282    229155  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65283    229325  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65284    229332  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
#
# ...

# %%
data.to_csv('test_file.csv')

# %%
data = data.iloc[0:500]

# %%
data.to_csv('test_file1.csv')

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('test_file1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  OBJECTID   PSS_Name  PSS_Code                   Feed_Name  \
# 0           0     24805  ANTERVEDI   1000734  11KV ANTHERVEDI PALLIPALEM
# 1           1     24806  ANTERVEDI   1000734  11KV ANTHERVEDI PALLIPALEM
# 2           2     24807  ANTERVEDI   1000734  11KV ANTHERVEDI PALLIPALEM
# 3           3     24808  ANTERVEDI   1000734  11KV ANTHERVEDI PALLIPALEM
# 4           4     24809  ANTERVEDI   1000734  11KV ANTHERVEDI PALLIPALEM
#
#    Feed_Code  DTR_Code Capacity   Fund_Agncy Scheme      State_Name  \
# 0    4435202  45901601   25 KVA  State Govt.         ANDHRA PRADESH
# 1    4435202  45901632   16 KVA  State Govt.         ANDHRA PRADESH
# 2    4435202  45901620   63 KVA  State Govt.         ANDHRA PRADESH
# 3    4435202  45901636   16 KVA  State Govt.         ANDHRA PRADESH
# 4    4435202  45901618  100 KVA  State Govt.         ANDHRA PRADESH
#
#    State_Code      Dist_Name  Dist_Code   Vil_Name  Vil_Code      Sub_dist_N  \
# ...

# %%
import folium

# %%
lat=20.5937
lang=78.9629
folium.Map(location=[lat,lang],zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
colors={'ES':'red' , 
'K-8':'blue'  ,        
'HS':'purple'   ,        
'Special':'green',   
'6/7-12':'brick',    
'K-12':'red',       
'MS':'gray',   
'ELC':'orange',   
       }

# %%
india_circle=folium.Map(location=[lat,lang],zoom_start=12)
for lat,lng,num in zip(df.geometry,df.geometry,range(1,df.shape[0])): 
         popup = folium.Popup(df['Feed_Name'][num], parse_html=True)
         folium.CircleMarker(
                    [lat,lng],
                    radius=6,
                    color=colors[df.iloc[num,-8]],
                    fill=True,
                    fill_color=colors[df.iloc[num,-8]],
                    fill_opacity=0.7,
                    popup=popup
            ).add_to(boston_circle)
boston_circle
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      59         try:
# ---> 60             float(coord)
#      61         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: 'POINT (9097597.674800001 1841486.414700001)'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-a279b10f564f> in <module>
# ----> 1 india_circle=folium.Map(location=[lat,lang],zoom_start=12)
#       2 for lat,lng,num in zip(df.geometry,df.geometry,range(1,df.shape[0])):
#       3          popup = folium.Popup(df['Feed_Name'][num], parse_html=True)
#       4          folium.CircleMarker(
#       5                     [lat,lng],
#
# ...
