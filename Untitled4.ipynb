# %%
# !pip install arcgis

# %%
viewshed = import_toolbox('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-703d89d74053> in <module>
# ----> 1 viewshed = import_toolbox('')
#
# NameError: name 'import_toolbox' is not defined

# %%
conda install -c conda-forge untangle

# %%
import os
import untangle  
from setuptools import find_packages, setup

pom = untangle.parse("pom.xml")
version = pom.project.version.cdata

where = os.path.join("src", "main", "python")
setup(
    name='filegdb',
    version=version,
    description='FileGDB',
    author='Mansour Raad',
    author_email='mraad@esri.com',
    python_requires='>=3.6',
    packages=find_packages(where=where),
    package_dir={'': where}
)
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# ~\anaconda3\lib\xml\sax\expatreader.py in feed(self, data, isFinal)
#     216             # except when invoked from close.
# --> 217             self._parser.Parse(data, isFinal)
#     218         except expat.error as e:
#
# ExpatError: syntax error: line 1, column 0
#
# During handling of the above exception, another exception occurred:
#
# SAXParseException                         Traceback (most recent call last)
# <ipython-input-4-308c73c758ce> in <module>
#       3 from setuptools import find_packages, setup
#       4
# ----> 5 pom = untangle.parse("pom.xml")
#       6 version = pom.project.version.cdata
#       7
#
# ~\anaconda3\lib\site-packages\untangle.py in parse(filename, **parser_features)
#     180             parser.parse(filename)
#     181         else:
# --> 182             parser.parse(StringIO(filename))
# ...

# %%
import geopandas as gpd

# %%
help(gpd)
# Out:
# Help on package geopandas:
#
# NAME
#     geopandas
#
# PACKAGE CONTENTS
#     _compat
#     _config
#     _vectorized
#     _version
#     array
#     base
#     conftest
#     datasets (package)
#     geodataframe
#     geoseries
#     io (package)
#     plotting
#     sindex
#     testing
#     tests (package)
#     tools (package)
#
# DATA
#     options = Options(
#       display_precision: None [default: Non...USE_PYGEO...
#
# VERSION
#     0.9.0
#
# FILE
#     c:\users\parul\anaconda3\lib\site-packages\geopandas\__init__.py

# %%
data = gpd.read_file('C:/Users/parul/anaconda3/machine learning and python projects/Untitled Folder/Test_Service_File_geodatabase.gdb')

# %%
data
# Out:
#        OBJECTID    PSS_Name PSS_Code                   Feed_Name Feed_Code  \
# 0         24805   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 1         24806   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 2         24807   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 3         24808   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 4         24809   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# ...         ...         ...      ...                         ...       ...
# 65280    228815  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65281    229030  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65282    229155  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65283    229325  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65284    229332  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
#
# ...

# %%
data
# Out:
#        OBJECTID    PSS_Name PSS_Code                   Feed_Name Feed_Code  \
# 0         24805   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 1         24806   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 2         24807   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 3         24808   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 4         24809   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# ...         ...         ...      ...                         ...       ...
# 65280    228815  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65281    229030  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65282    229155  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65283    229325  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65284    229332  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
#
# ...

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.head()
# Out:
#    OBJECTID   PSS_Name PSS_Code                   Feed_Name Feed_Code  \
# 0     24805  ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 1     24806  ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 2     24807  ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 3     24808  ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 4     24809  ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
#
#     DTR_Code Capacity   Fund_Agncy Scheme      State_Name State_Code  \
# 0  045901601   25 KVA  State Govt.         ANDHRA PRADESH         37
# 1  045901632   16 KVA  State Govt.         ANDHRA PRADESH         37
# 2  045901620   63 KVA  State Govt.         ANDHRA PRADESH         37
# 3  045901636   16 KVA  State Govt.         ANDHRA PRADESH         37
# 4  045901618  100 KVA  State Govt.         ANDHRA PRADESH         37
#
#        Dist_Name Dist_Code   Vil_Name Vil_Code      Sub_dist_N Sub_Dist_C  \
# ...

# %%
data.tail()
# Out:
#        OBJECTID    PSS_Name PSS_Code        Feed_Name Feed_Code   DTR_Code  \
# 65280    228815  MANGAMPADU  1000167  11KV MANGAMPADU   4332201  040212819
# 65281    229030  MANGAMPADU  1000167  11KV MANGAMPADU   4332201  040212820
# 65282    229155  MANGAMPADU  1000167  11KV MANGAMPADU   4332201  040212821
# 65283    229325  MANGAMPADU  1000167  11KV MANGAMPADU   4332201  040212805
# 65284    229332  MANGAMPADU  1000167  11KV MANGAMPADU   4332201  040212806
#
#       Capacity   Fund_Agncy Scheme      State_Name State_Code      Dist_Name  \
# 65280   15 KVA  State Govt.         ANDHRA PRADESH         37  East Godavari
# 65281   15 KVA  State Govt.         ANDHRA PRADESH         37  East Godavari
# 65282   15 KVA  State Govt.         ANDHRA PRADESH         37  East Godavari
# 65283   15 KVA  State Govt.         ANDHRA PRADESH         37  East Godavari
# 65284   15 KVA  State Govt.         ANDHRA PRADESH         37  East Godavari
#
# ...

# %%
data1 = data.iloc[0:1000]

# %%
data1
# Out:
#      OBJECTID        PSS_Name PSS_Code                   Feed_Name Feed_Code  \
# 0       24805       ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 1       24806       ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 2       24807       ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 3       24808       ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 4       24809       ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# ..        ...             ...      ...                         ...       ...
# 995     26371  SAKHINETIPALLI  1000422          11KV S.K.PALLI MHQ   4435104
# 996     26374      LAKKAVARAM   100012             11KV LAKKAVARAM   4434201
# 997     26376  SAKHINETIPALLI  1000422          11KV S.K.PALLI MHQ   4435104
# 998     26377      LAKKAVARAM   100012             11KV LAKKAVARAM   4434201
# 999     26379      LAKKAVARAM   100012             11KV LAKKAVARAM   4434201
#
# ...

# %%
data1.to_file('1st.shp', drivers = 'ESRI Shapefile')

# %%
data.columns
# Out:
# Index(['OBJECTID', 'PSS_Name', 'PSS_Code', 'Feed_Name', 'Feed_Code',
#        'DTR_Code', 'Capacity', 'Fund_Agncy', 'Scheme', 'State_Name',
#        'State_Code', 'Dist_Name', 'Dist_Code', 'Vil_Name', 'Vil_Code',
#        'Sub_dist_N', 'Sub_Dist_C', 'DSCOM_CODE', 'geometry'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# Out:
# In C:\Users\parul\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\parul\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\parul\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\parul\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
# !pip install pyforest

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
len(data)
# Out:
# 65285

# %%
data.plot(cmap = 'jet')
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['OBJECTID', 'PSS_Name', 'PSS_Code', 'Feed_Name', 'Feed_Code',
#        'DTR_Code', 'Capacity', 'Fund_Agncy', 'Scheme', 'State_Name',
#        'State_Code', 'Dist_Name', 'Dist_Code', 'Vil_Name', 'Vil_Code',
#        'Sub_dist_N', 'Sub_Dist_C', 'DSCOM_CODE', 'geometry'],
#       dtype='object')

# %%
data.plot(cmap = 'jet', column = 'DTR_Code', figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
from IPython.display import IFrame
documentation = IFrame(src='https://ipyleaflet.readthedocs.io/en/latest/', width=1000, height=600)
display(documentation)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://ipyleaflet.readthedocs.io/en/latest/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles

m = Map(center=(17.3213, 82.0407), zoom=9)
m
# Out:
# Map(center=[17.3213, 82.0407], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
from ipyleaflet import Map, GeoJSON, GeoData
import geopandas, pandas as pd, numpy as np

data = gpd.read_file('C:/Users/parul/anaconda3/machine learning and python projects/Untitled Folder/Test_Service_File_geodatabase.gdb')

m = Map(center=(17.3213, 82.0407), zoom=15)

numpoints = 10
center = (17.3213, 82.0407)

df = pd.DataFrame(
    {'Conc': 1 * np.random.randn(numpoints) + 17,
     'Longitude': 0.0004 * np.random.randn(numpoints) + center[0],
     'Latitude': 0.0004 * np.random.randn(numpoints) + center[1]})

gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))

geo_data = GeoData(geo_dataframe = gdf,
    style={'color': 'black', 'radius':8, 'fillColor': '#3366cc', 'opacity':0.5, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
    hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
    point_style={'radius': 5, 'color': '
                 red', 'fillOpacity': 0.8, 'fillColor': 'blue', 'weight': 3},
    name = 'Release')

m.add_layer(geo_data)
m
# Out:
#   File "<ipython-input-24-b4ad195728be>", line 22
#     point_style={'radius': 5, 'color': '
#                                         ^
# SyntaxError: EOL while scanning string literal

# %%
from ipyleaflet import Map, GeoData, basemaps, LayersControl
import geopandas
import json

countries = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
rivers = geopandas.read_file("https://www.naturalearthdata.com/http//www.naturalearthdata.com/download/10m/physical/ne_10m_rivers_lake_centerlines.zip")

m = Map(center=(52.3,8.0), zoom = 3, basemap= basemaps.Esri.WorldTopoMap)

geo_data = GeoData(geo_dataframe = countries,
                   style={'color': 'black', 'fillColor': '#3366cc', 'opacity':0.05, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
                   hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
                   name = 'Countries')

rivers_data = GeoData(geo_dataframe = rivers,
                   style={'color': 'purple', 'opacity':3, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
                   hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
                   name = 'Rivers')

m.add_layer(rivers_data)
m.add_layer(geo_data)
m.add_control(LayersControl())

m

# %%
data1 = data.iloc[0:400]

# %%
data1

# %%
from ipyleaflet import Map, GeoData, basemaps, LayersControl
import geopandas as gpd
import json

data2 = gpd.read_file('C:/Users/parul/anaconda3/machine learning and python projects/Untitled Folder/Test_Service_File_geodatabase.gdb')
data = gpd.read_file('C:/Users/parul/anaconda3/machine learning and python projects/Untitled Folder/Test_Service_File_geodatabase.gdb')

m = Map(center=(17.3213, 82.0407), zoom = 3, basemap= basemaps.Esri.WorldTopoMap)

geo_data = GeoData(geo_dataframe = data2,
                   style={'color': 'black', 'fillColor': '#3366cc', 'opacity':0.05, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
                   hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
                   name = 'data2')

df_data = GeoData(geo_dataframe = data1,
                   style={'color': 'purple', 'opacity':3, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
                   hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
                   name = 'data1')

m.add_layer(df_data)
m.add_control(LayersControl())

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2b86d98af880> in <module>
#      13                    name = 'data2')
#      14
# ---> 15 df_data = GeoData(geo_dataframe = data1,
#      16                    style={'color': 'purple', 'opacity':3, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
#      17                    hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
#
# NameError: name 'data1' is not defined

# %%
data = gpd.read_file('C:/Users/parul/anaconda3/machine learning and python projects/Untitled Folder/Test_Service_File_geodatabase.gdb')

# %%
from ipyleaflet import Map, GeoData, basemaps, LayersControl
import geopandas
import json

data = gpd.read_file('C:/Users/parul/anaconda3/machine learning and python projects/Untitled Folder/Test_Service_File_geodatabase.gdb')
m = Map(center=(17.3213, 82.0407), zoom=3, basemaps= basemaps.Esri.WorldTopoMap)
geo_data = GeoData(geo_dataframe = data,
                   style={'color': 'black', 'fillColor': '#3366cc', 'opacity':0.05, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
                   hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
                   name = 'Countries')


m.add_layer(geo_data)
m.add_control(LayersControl())

m

# %%
data.to_shp('data.shp')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-80beed9247d6> in <module>
# ----> 1 data.to_shp('data.shp')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'to_shp'

# %%
data.to_file('MyGeometries.shp', driver='ESRI Shapefile')

# %%
import geopandas as gpd
gdf = gpd.read_file('C:/Users/parul/anaconda3/machine learning and python projects/Untitled Folder/MyGeometries.shp')
print (gdf)
# Out:
#        OBJECTID    PSS_Name PSS_Code                   Feed_Name Feed_Code  \
# 0         24805   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 1         24806   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 2         24807   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 3         24808   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# 4         24809   ANTERVEDI  1000734  11KV ANTHERVEDI PALLIPALEM   4435202
# ...         ...         ...      ...                         ...       ...
# 65280    228815  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65281    229030  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65282    229155  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65283    229325  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
# 65284    229332  MANGAMPADU  1000167             11KV MANGAMPADU   4332201
#
# ...

# %%
# %matplotlib inline
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf.plot(column='LUCODE', cmap=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LUCODE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
